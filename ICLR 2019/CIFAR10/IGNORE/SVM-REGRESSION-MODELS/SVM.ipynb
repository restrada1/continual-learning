# %%
from sklearn import datasets ## imports datasets from scikit-learn
from sklearn import linear_model
import pandas as pd
import matplotlib 
#matplotlib.use("Agg") 
import matplotlib.pyplot as plt
# %matplotlib inline
#data = datasets.load_boston()

# %%
filename='../final_test/1_MSE_final'
df=pd.read_hdf(filename)
X=df[['skill','caluclated_mse']]
y=df[['Accuracy']]
filename='../MSE_Fixed_Iter/2_MSE_fixed_iter'
df_test=pd.read_hdf(filename)
# for i in range(1,10):
#     filename= ' ../MSE_Fixed_Iter/' +str(i)+'_MSE_fixed_iter'
#     df_skill=pd.read_hdf(filename)
#     print(df_skill.tail(i))
len(df_test)
# Out:
# 198

# %%
df
# Out:
#    batch_idx  skill  caluclated_mse   Accuracy  Actual_Accuracy  Resend_len
# 0        1.0    0.0        0.006492  35.033333             84.0         3.0
# 0        2.0    0.0        0.002527  33.333333             84.0         3.0
# 0        3.0    0.0        0.001326  66.666667             84.0         3.0
# 0        4.0    0.0        0.001354  66.666667             84.0         3.0
# 0        5.0    0.0        0.001212  66.666667             84.0         3.0
# 0        6.0    0.0        0.001096  67.133333             84.0         3.0
# 0        7.0    0.0        0.001029  66.666667             84.0         3.0
# 0        8.0    0.0        0.001024  66.666667             84.0         3.0
# 0        9.0    0.0        0.000980  66.666667             84.0         3.0
# 0       10.0    0.0        0.000970  66.666667             84.0         3.0
# 0       11.0    0.0        0.000958  66.666667             84.0         3.0
# ...

# %%
df_test=df_test[df_test.skill==0.00]
df_test
# Out:
#     batch_idx  skill  caluclated_mse   Accuracy  Actual_Accuracy  Resend_len
# 0         1.0    0.0    1.818782e-04  78.800000             84.0         4.0
# 0         2.0    0.0    4.121623e-04  70.533333             84.0         5.0
# 0         3.0    0.0    5.775380e-04  77.233333             84.0         5.0
# 0         4.0    0.0    4.185959e-04  70.866667             84.0         6.0
# 0         5.0    0.0    1.097441e-03  77.300000             84.0         6.0
# 0         6.0    0.0    3.298872e-04  74.733333             84.0         6.0
# 0         7.0    0.0    1.681448e-04  74.666667             84.0         4.0
# 0         8.0    0.0    1.831597e-04  77.600000             84.0         6.0
# 0         9.0    0.0    1.447088e-04  74.166667             84.0         5.0
# 0        10.0    0.0    1.018548e-04  78.300000             84.0         5.0
# 0        11.0    0.0    1.387449e-04  76.166667             84.0         4.0
# ...

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
# ...

# %%
target = pd.DataFrame(data.target, columns=["MEDV"])
target.head(10)
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2
# 5  28.7
# 6  22.9
# 7  27.1
# 8  16.5
# 9  18.9

# %%
# X = df
# y = target['MEDV']
lm = linear_model.LinearRegression()
model = lm.fit(X,y)

# %%
target[0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1f72a264b2d6> in <module>()
# ----> 1 target[0:5]
#
# NameError: name 'target' is not defined

# %%
predictions = lm.predict(X)
print((predictions)[0:5])
# Out:
# [[24.18821323]
#  [57.55907776]
#  [67.66554189]
#  [67.42836893]
#  [68.62510572]]

# %%
lm.score(X,y)
# Out:
# 0.65723534766196

# %%
from sklearn import svm
from sklearn.svm import SVR

import numpy as np

# %%
clf = svm.SVR(gamma='scale', C=1.0, epsilon=0.2)
>>> n_samples, n_features = 10, 5
>>> np.random.seed(0)
>>> y = np.random.randn(n_samples)
>>> X = np.random.randn(n_samples, n_features)
# Fit regression model
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
y_rbf = svr_rbf.fit(X, y).predict(X)
y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)

# %%
y=np.array(df['Accuracy'])
y
# Out:
# array([35.03333333, 33.33333333, 66.66666667, 66.66666667, 66.66666667,
#        67.13333333, 66.66666667, 66.66666667, 66.66666667, 66.66666667,
#        66.66666667, 66.66666667, 66.66666667, 66.66666667, 79.63333333,
#        77.63333333, 67.66666667, 80.8       , 81.93333333, 82.43333333,
#        81.1       , 82.        , 83.26666667])

# %%
X=np.array(X)
y=np.array(df['Accuracy'])#.values

# %%
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
y_rbf = svr_rbf.fit(X, y).predict(X)
y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)

# %%
len(y)
# Out:
# 23

# %%
# #############################################################################
# Look at the results
lw = 2
plt.scatter(X, y, color='darkorange', label='data')
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-93235a88ee44> in <module>()
#       3 # Look at the results
#       4 lw = 2
# ----> 5 plt.scatter(X, y, color='darkorange', label='data')
#       6 plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
#       7 plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# ...

# %%
clf.fit(np.array(X),np.array(df['Accuracy'].values))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-9963daa71f44> in <module>()
# ----> 1 clf.fit(np.array(X),np.array(df['Accuracy'].values))
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
# ...

# %%
X.dtypes
# Out:
# skill             float64
# caluclated_mse    float64
# dtype: object
